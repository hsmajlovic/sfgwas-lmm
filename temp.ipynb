# %%
import numpy as np


x = np.fromfile("example_data/party1/combined.bin", dtype=np.uint8)

# %%
stacked_x = np.hstack((x, x, x))

# %%
stacked_x
# Out:
# array([1, 1, 0, ..., 1, 1, 0], shape=(3000000,), dtype=uint8)

# %%
with open("example_data/party1/combined_filtered.bin", 'wb') as f:
    stacked_x[:100 * 8192 * 3].tofile(f)
